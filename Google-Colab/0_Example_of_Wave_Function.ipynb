# %% [markdown]
# <a href="https://colab.research.google.com/github/jtinkane-code/my-first-binder/blob/main/Google-Colab/0_Example_of_Wave_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Example of a wave function: the Gaussian wave packet

# %% [markdown]
# Contributors: [Ismaila Dabo](https://scholar.google.com/citations?user=rN299m0AAAAJ&hl=en)
#
# Fill in the blanks!

# %%
# install libraries for numerical calculations and plotting.
import numpy as np
import matplotlib.pyplot as plt
import tqdm

# discretize space
dx = 0.5
x = np.arange(-250, 251, dx)
nx = len(x)

# discretize time
dt = 0.25
t = np.arange(0, 151, dt)
nt = len(t)

# initialize wave packet
x0 = 0 #####
k0 = 0.5
sigma0 = 15 #####
psi = 1/ (2* np.pi * sigma0 **2 ) ** 0.25*np.exp(-(x - x0)**2 / (4 * sigma0**2)) * np.exp(1j * k0 * x)  #####

#psi = np.exp(-(x - x0)**2 / (4 * sigma0**2)) * np.exp(1j * k0 * x)

# plot the wave packet
fig, ax = plt.subplots()
ax.plot(x, np.real(psi), label='Re psi') #####
ax.plot(x, np.imag(psi), label='Im psi') #####
ax.plot(x, np.abs(psi)**2, label='| psi |^2')

# configure the plot
ax.set_xlim(-100, 100) #####
ax.set_xlabel('position (a.u.)')
ax.set_ylabel('wavefunction')
ax.legend()
ax.grid()

print(f'Integral: {dx*np.sum(np.abs(psi)**2)}')
# Out:
# Integral: 1.0

# %% [markdown]
# ## Solution

# %%
import numpy as np
import matplotlib.pyplot as plt
import tqdm


# discretize space
dx = 0.5
x = np.arange(-250, 251, dx)
nx = len(x)

# discretize time
dt = 0.25
t = np.arange(0, 151, dt)
nt = len(t)

# initialize wave packet
x0 = 50
k0 = 1.0
sigma0 = 10
psi = (2 * sigma0**2 * np.pi)**-0.25 * np.exp(-(x - x0)**2 / (4 * sigma0**2)) * np.exp(1j * k0 * x)

# plot the wave packet
fig, ax = plt.subplots()
ax.plot(x, np.real(psi), label='Re $\psi$')
ax.plot(x, np.imag(psi), label='Im $\psi$')
ax.plot(x, np.abs(psi)**2, label='$| \psi |^2$')

# configure the plot
ax.set_xlim(0, 100)
ax.set_xlabel('position (a.u.)')
ax.set_ylabel('wavefunction')
ax.legend()
ax.grid()

print(f'Integral: {dx*np.sum(np.abs(psi)**2)}')
# Out:
# <>:24: SyntaxWarning: invalid escape sequence '\p'
# <>:25: SyntaxWarning: invalid escape sequence '\p'
# <>:26: SyntaxWarning: invalid escape sequence '\p'
# <>:24: SyntaxWarning: invalid escape sequence '\p'
# <>:25: SyntaxWarning: invalid escape sequence '\p'
# <>:26: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipython-input-816532283.py:24: SyntaxWarning: invalid escape sequence '\p'
#   ax.plot(x, np.real(psi), label='Re $\psi$')
# /tmp/ipython-input-816532283.py:25: SyntaxWarning: invalid escape sequence '\p'
#   ax.plot(x, np.imag(psi), label='Im $\psi$')
# /tmp/ipython-input-816532283.py:26: SyntaxWarning: invalid escape sequence '\p'
#   ax.plot(x, np.abs(psi)**2, label='$| \psi |^2$')
# Integral: 1.0
